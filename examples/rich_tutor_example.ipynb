# %% [markdown]
# ## ➕ Exercise 1 — Add Two Numbers
#
# Implement the function `add(a, b)` that returns the sum of `a` and `b`.

# %%
def add(a, b):
    # Write your solution here
    return a - b  # Bug: subtracting instead of adding
